# %% [markdown]
# 1. Array 1 Dimensi

# %%
# Deklarasi array menggunakan list
angka = [10, 20, 30, 40, 50]
print("Array dengan list:", angka)
# Out:
# Array dengan list: [10, 20, 30, 40, 50]

# %%
import array
angka = array.array('i', [10, 20, 30, 40, 50])
print("Array dengan modul array:", angka)
# Out:
# Array dengan modul array: array('i', [10, 20, 30, 40, 50])

# %%
import numpy as np
angka = np.array([10, 20, 30, 40, 50])
print("Array dengan NumPy:", angka)
# Out:
# Array dengan NumPy: [10 20 30 40 50]

# %%
import numpy as np
angka = np.array([1, 2, 3, 4, 5])
print("Array satu dimensi:", angka)
# Out:
# Array satu dimensi: [1 2 3 4 5]

# %%
matriks = np.array([[1, 2], [3, 4], [5, 6]])
print("Array dua dimensi:", matriks)
# Out:
# Array dua dimensi: [[1 2]
#  [3 4]
#  [5 6]]

# %%
array3D = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
print("Array tiga dimensi:", array3D)
# Out:
# Array tiga dimensi: [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
# Deklarasi array kosong
angka = []
# Inisialisasi array dengan elemen
angka = [10, 20, 30, 40, 50]
# Akses elemen
print("Elemen pertama:", angka[0])
print("Elemen terakhir:", angka[-1])

# Menambahkan elemen baru
angka.append(60)
print("Setelah append:", angka)
# Menghapus elemen
angka.remove(30)
print("Setelah remove:", angka)

# Iterasi array
for nilai in angka:
    print("Nilai:", nilai)
# Out:
# Elemen pertama: 10
# Elemen terakhir: 50
# Setelah append: [10, 20, 30, 40, 50, 60]
# Setelah remove: [10, 20, 40, 50, 60]
# Nilai: 10
# Nilai: 20
# Nilai: 40
# Nilai: 50
# Nilai: 60

# %%
# Akses Elemen
print("Elemen pertama:", angka[0])

# Penambahan Elemen
angka =np.append(angka, 60)
print("Setelah penambahan:", angka)

# Penghapusan/Perubahan Elemen
angka = np.delete(angka, 2) # Menghapus elemen pada indeks ke-2
print ("Setelah penghapusan:", angka)

# Perhitungan Panjang Array
print("Jumlah elemen:", len(angka))
# Out:
# Elemen pertama: 2440506076
# Setelah penambahan: [2440506076 2440506077 2440506078 2440506079         60]
# Setelah penghapusan: [2440506076 2440506077 2440506079         60]
# Jumlah elemen: 4

# %% [markdown]
# LATIHAN 1:
# Buatlah array yang berisi NPM Anda diikuti dengan 4 NPM sebelum ATAU setelah Anda kemudian tampilkan isi aray tersebut!

# %%
# LATIHAN 1

# Deklarasi array kosong
data =[]

# Inisialisasi array dengan elemen
angka = [2440506076, 2440506077, 2440506078, 2440506079]

# Menampilkan isi NPM
print("isi NPM angka:", angka)
# Out:
# isi NPM angka: [2440506076, 2440506077, 2440506078, 2440506079]

# %%
# a. Mengakses elemen Array
print("Elemen pertama:", angka[0]) # Elemen pertama
print("Elemen terakhir:", angka[-1]) # Elemen terakhir

# b. Menambah Elemen Aray
# Menambah elemen menggunakan append()
angka.append(60)
print("Array setelah penambahan elemen:", angka)
# Menambah elemen menggunakan insert()
angka.insert(2, 25)  # Menyisipkan 25 di indeks ke-2
print("Array setelah penambahan elemen dengan insert:", angka)

# c. Menghapus Elemen Array
# Menghapus elemen menggunakan remove()
angka.remove(25)  # Menghapus nilai 25
print("Array setelah menghapus elemen 25:", angka)
# Menghapus elemen menggunakan pop()
angka.pop(2)  # Menghapus elemen pada indeks ke-2
print("Array setelah menghapus elemen pada indeks ke-2:", angka)

# d. Mengubah Elemen Array
# Mengubah elemen pada indeks 0
angka[0] = 100
print("Array setelah mengubah elemen pertama:", angka)

# %% [markdown]
# LATIHAN 2 :
# Tambahkan nilai NPM Anda (2 digit terakhir) ke dalam array angka dan hapus elemen pertama!

# %%
# LATIHAN 2

angka = [2440506076, 2440506077, 2440506078, 2440506079]

print("Sebelum nilai NPM ditambah:\nangka: ", ", ".join(list(map(str, angka))))

angka.append(80)
angka.pop(0)

print("\nSetelah nilai NPM ditambah:\nangka: ", ", ".join(list(map(str, angka))))
# Out:
# Sebelum nilai NPM ditambah:
# angka:  2440506076, 2440506077, 2440506078, 2440506079
#
# Setelah nilai NPM ditambah:
# angka:  2440506077, 2440506078, 2440506079, 80

# %% [markdown]
# 2. Iterasi dan Operasi pada Array

# %%
# 2.1 Iterasi dengan perulangan

angka = [10, 20, 30, 40]

for nilai in angka:
    print("Nilai:", nilai)
# Out:
# Nilai: 10
# Nilai: 20
# Nilai: 30
# Nilai: 40

# %% [markdown]
# LATIHAN 3 : Buat program untuk menampilkan semua nama Fakultas di Untidar dengan array dan perulangan!

# %%
# LATIHAN 3

daftar_fakultas = [
    "Fakultas Ekonomi",
    "Fakultas Keguruan Dan Ilmu Pendidikan",
    "Fakultas Ilmu Sosial Dan Ilmu Politik",
    "Fakultas Pertanian",
    "Fakultas Teknik"
]

for fakultas in daftar_fakultas:
  print(fakultas)
# Out:
# Fakultas Ekonomi
# Fakultas Keguruan Dan Ilmu Pendidikan
# Fakultas Ilmu Sosial Dan Ilmu Politik
# Fakultas Pertanian
# Fakultas Teknik

# %%
#2.2 Operasi Matematika Sederhana

angka = [10, 20, 30, 40]

print("Jumlah total:", sum(angka))
print("Nilai maksimum:", max(angka))
print("Nilai minimum:", min(angka))
# Out:
# Jumlah total: 100
# Nilai maksimum: 40
# Nilai minimum: 10

# %% [markdown]
# LATIHAN 4 : Buatlah array yang berisi harga barang dan hitung jumlah elemen dari array tersebut!

# %%
# LATIHAN 4

harga_barang = [10000, 20000, 30000, 40000, 80000, 100000]

jumlah_elemen = len(harga_barang)
jumlah_total = sum(harga_barang)

print("Daftar harga barang:", harga_barang)
print("Jumlah total:", jumlah_total)
print("Jumlah elemen dalam array:", jumlah_elemen)
# Out:
# Daftar harga barang: [10000, 20000, 30000, 40000, 80000, 100000]
# Jumlah total: 280000
# Jumlah elemen dalam array: 6

# %% [markdown]
# 3. Array 2 Dimensi

# %%
# 3.1 Deklarasi dan inisialisasi Array 2D

# Deklarasi array 2D
matriks = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Menampilkan isi array 2D
print("Isi array 2D:")
for baris in matriks:
    print(baris)
# Out:
# Isi array 2D:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %% [markdown]
# LATIHAN 5 : Buatlah array 2D yang berisi 3 baris dan 4 kolom,lalu tampilkan isi array tersebut menggunakan perulangan!

# %%
# LATIHAN 5

matriks = [
    [120, 110, 100],
    [90, 80, 70],
    [60, 50, 40],
    [30, 20, 10]
]

print("Isi array 2D:")
for baris in matriks:
  print(baris)
# Out:
# Isi array 2D:
# [120, 110, 100]
# [90, 80, 70]
# [60, 50, 40]
# [30, 20, 10]

# %%
# 3.2 Operasi Dasar pada Array 2D
# a. Mengakses Elemen Array 2D

# Mengakses elemen pada baris ke-1, kolom ke-2 (indeks [0] [1])
print("Elemen pada baris 1, kolom 2:", matriks[0][1])

# Mengakses elemen terakhir (baris ke-3 kolom ke-3
print("Elemen terakhir:", matriks[-1][-1])
# Out:
# Elemen pada baris 1, kolom 2: 110
# Elemen terakhir: 10

# %% [markdown]
# LATIHAN 6 : Akses elemen pada baris 2 kolom 4 dari array 2 dimensi yang telah Anda buat pada Latihan 5!

# %%
# LATIHAN 6

matriks = [
    [120, 110, 100],
    [90, 80, 70],
    [60, 50, 40],
    [30, 20, 10]
]

print(f"Baris 2 kolom 4: {matriks[3][1]}")
# Out:
# Baris 2 kolom 4: 20

# %%
# b. Menambah Elemen ke Array 2D
matriks.append([10, 11, 12])
print("Array setelah menambahkan baris baru:", matriks)

# Menambahkan elemen pada baris ke-2
matriks[1].append(99)
print("Array setelah menambahkan elemen di baris ke-2:", matriks)
# Out:
# Array setelah menambahkan baris baru: [[120, 110, 100], [90, 80, 70], [60, 50, 40], [30, 20, 10], [10, 11, 12]]
# Array setelah menambahkan elemen di baris ke-2: [[120, 110, 100], [90, 80, 70, 99], [60, 50, 40], [30, 20, 10], [10, 11, 12]]

# %% [markdown]
# LATIHAN 7 : Tambahkan baris baru yang berisi tanggal lahir, bulan lahir,2 digit awal tahun lahir, dan digit terakhir tahun lahir Anda, dan tampilkan dalam bentuk baris dan kolom!

# %%
# LATIHAN 7
# Tanggal lahir saya : 28 Mei (05) Tahun: 2005
matriks = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

matriks.append([28, 5, 20, 5])

for baris in matriks:
  print(baris)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
# [28, 5, 20, 5]

# %%
# c. Menghapus Elemen dari Array 2D
# Menghapus elemen tertentu dari baris ke-1
matriks[0].remove(2)
print("Array setelah menghapus elemen 2 dari baris pertama:", matriks)

# Menghapus elemen pada indeks tertentu dari baris ke-2
matriks[1].pop(1)
print("Array setelah menghapus elemen indeks ke-1 dari baris ke-2:", matriks)
# Out:
# Array setelah menghapus elemen 2 dari baris pertama: [[1, 3], [4, 5, 6], [7, 8, 9], [28, 5, 20, 5]]
# Array setelah menghapus elemen indeks ke-1 dari baris ke-2: [[1, 3], [4, 6], [7, 8, 9], [28, 5, 20, 5]]

# %% [markdown]
# LATIHAN 8 : Modifikasilah array pada latihan sebelumnya untuk menghapus elemen ke-3 dari baris terakhir!

# %%
# LATIHAN 8

matriks = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

matriks.append([28, 5, 20, 5])
matriks[len(matriks) - 1].pop()

for baris in matriks:
  print(baris)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
# [28, 5, 20]

# %%
# d. Mengubah Elemen dalam Array 2D
# Mengubah elemen pada  baris ke-3, kolom ke-2
matriks[2] [1] = 88
print("Array setelah mengubah elemen pada baris ke-3, kolom ke-2:", matriks)
# Out:
# Array setelah mengubah elemen pada baris ke-3, kolom ke-2: [[1, 2, 3], [4, 5, 6], [7, 88, 9], [28, 5, 20]]

# %% [markdown]
# LATIHAN 9 : Ubah elemen pada baris terakhir kolom terakhir dengan tanggal hari ini!

# %%
# LATIHAN 9

from datetime import date
matriks = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Mengubah elemen pada baris terakhir dan kolom terakhir dengan tanggal hari ini
matriks[-1][-1] = date.today()

for baris in matriks:
    print(baris)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, datetime.date(2025, 2, 20)]

# %% [markdown]
# 4. Studi Kasus Sederhana

# %%
# 4.1 Menyimpan Daftar Belanja
belanja = ["Beras", "Gula", "Minyak"]
belanja.append("Teh")
belanja.remove("Gula")
print("Daftar Belanja terbaru:", belanja)
# Out:
# Daftar Belanja terbaru: ['Beras', 'Minyak', 'Teh']

# %% [markdown]
# LATIHAN 10 : Buat daftar belanja Anda sendiri dan modifikasi isinya!

# %%
# LATIHAN 10

belanja = ["Skin Aspirants Fanny", "Script Ling collector Serene plume", "Skin basic Alucard hijau"]
belanja.append("Skin Ling epic")
belanja.remove("Script Ling collector Serene plume")
print("Daftar Belanja terbaru:", belanja)
# Out:
# Daftar Belanja terbaru: ['Skin Aspirants Fanny', 'Skin basic Alucard hijau', 'Skin Ling epic']

# %%
# 4.2 Implementasi pada Permainan Sederhana

# Ukuran peta
size = 10

# Membuat peta dengan harta karun tersembunyi
treasure_map = ["_" for _ in range(size)]

# Tentukan lokasi harta karun secara manual
print(f"Selamat datang di Treasure Hunt! Peta memiliki {size} lokasi (0 hingga {size-1}).")
treasure_index = int(input(f"Masukkan lokasi harta karun (0-{size-1}): "))
while treasure_index < 0 or treasure_index >= size:
    print("Lokasi tidak valid. Masukkan angka dalam rentang yang benar.")
    treasure_index = int(input(f"Masukkan lokasi harta karun (0-{size-1}):"))

treasure_map[treasure_index] = "X" # Menyembunyikan harta karun di lokasi yang dipilih

# Fungsi untuk memulai permainan
def play_treasure_hunt() :
    print("\nHarta karun telah disembunyikan! Sekarang giliran pemain menebak.")
    print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")

    # Loop Permainan
    while True:
          # Menampilkan peta tersembunyi kepada pemain
          print("\nPeta saat ini: ", ["_" for _ in range(size)])  #  Peta tersembunyi

          # Input pemain
          try:
              guess = int(input(f"Masukkan indeks tebakanmu (0-{size-1}): "))
          except ValueError:
              print("Masukkan angka yang valid!")
              continue

          # Validasi input
          if guess < 0 or guess >= size:
              print("Indeks tidak valid, pilih antaara 0 hingga", size-1)
              continue

          # Mengecek apakah tebakan benar'
          if treasure_map[guess] == "X":
              print("Selamat! Kamu menemukan harta karun di lokasi:", guess)
              break
          else:
              print("Tidak ada harta di lokasi ini. Coba lagi!")

    print("Terima kasih sudah bermain!")

# Jalankan permainan
play_treasure_hunt()
# Out:
# Selamat datang di Treasure Hunt! Peta memiliki 10 lokasi (0 hingga 9).
# Masukkan lokasi harta karun (0-9): 5
#
# Harta karun telah disembunyikan! Sekarang giliran pemain menebak.
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0-9): 5
# Selamat! Kamu menemukan harta karun di lokasi: 5
# Terima kasih sudah bermain!

# %% [markdown]
# *Tuliskan analisis Anda mengenai baris kode"Treasure hunt" ini beserta outputnya!*
#
# D. TUGAS
# Modifikasi game "Treasure Hunt"agar dapat melakukan fungsi sebagai berikut:
#
#   a. Input ukuran peta yang di inginkan.
#
#   b. Program dapat secara otomatis mengacak lokasi harta karun. Hint: gunakan library random.

# %%
# Jawaban Tugas A : Input ukuran yang di inginkan

size =int(input("Masukkan ukuran peta: "))

treasure_map = ["_" for _ in range(size)]

print(f"selamat datang di Treasure Hunt ! Peta memiliki {size} lokasi (0 hingga {size-1}). ")
treasure_index = int(input(f"Masukan lokasi harta karun (0 hingga {size-1}): "))
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentan yang benar.")
  treasure_index = int(input(f"Masukan lokasi harta karun (0 hingga {size-1}): "))

treasure_map[treasure_index] = "X"

def play_treasure_hunt():
  print ("\nHarta karun telah disembunyikan! Sekarang giliran pemain menebak")
  print ("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  while True:
    print ("\nPeta saat ini: ", ["_" for _ in range(size)])
    try:
      guess = int(input(f"Masukkan indeks tebakanmu (0 hingga {size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue

    if guess < 0 or guess >= size:
      print("Indeks tidak valid, pilih antara 0 hingga", size-1)
      continue

    if treasure_map[guess] == "X":
      print("Selamat! Kamu menemukan harta karus di lokasi:", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini. Coba lagi!")

play_treasure_hunt()
# Out:
# Masukkan ukuran peta: 2
# selamat datang di Treasure Hunt ! Peta memiliki 2 lokasi (0 hingga 1).
# Masukan lokasi harta karun (0 hingga 1): 1
#
# Harta karun telah disembunyikan! Sekarang giliran pemain menebak
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_']
# Masukkan indeks tebakanmu (0 hingga 1): 1
# Selamat! Kamu menemukan harta karus di lokasi: 1

# %%
# Jawaban Tugas B : Program dapat secara otomatis mengacak lokasi harta karun. Hint: gunakan library random.

import random

size = 10

treasure_map = ["_" for _ in range(size)]

print(f"selamat datang di Treasure Hunt ! Peta memiliki {size} lokasi (0 hingga {size-1}). ")
treasure_index = random.randint(0, size-1)
print(f"Harta karun telah disembunyikan di lokasi acak. Cobalah untuk menemukannya!")
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentan yang benar.")
  treasure_index = int(input(f"Masukan lokasi harta karun (0 hingga {size-1}): "))

treasure_map[treasure_index] = "X"

def play_treasure_hunt():
  print ("\nHarta karun telah disembunyikan! Sekarang giliran pemain menebak")
  print ("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  while True:
    print ("\nPeta saat ini: ", ["_" for _ in range(size)])
    try:
      guess = int(input(f"Masukkan indeks tebakanmu (0 hingga {size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue

    if guess < 0 or guess >= size:
      print("Indeks tidak valid, pilih antara 0 hingga", size-1)
      continue

    if treasure_map[guess] == "X":
      print("Selamat! Kamu menemukan harta karus di lokasi:", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini. Coba lagi!")

play_treasure_hunt()
# Out:
# selamat datang di Treasure Hunt ! Peta memiliki 10 lokasi (0 hingga 9).
# Harta karun telah disembunyikan di lokasi acak. Cobalah untuk menemukannya!
#
# Harta karun telah disembunyikan! Sekarang giliran pemain menebak
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 9): 3
# Tidak ada harta di lokasi ini. Coba lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 9): 1
# Tidak ada harta di lokasi ini. Coba lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 9): 2
# Tidak ada harta di lokasi ini. Coba lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 9): 4
# Selamat! Kamu menemukan harta karus di lokasi: 4

# %%
# Jawaban Gabungan A dan B
import random


size =int(input("Masukkan ukuran peta: "))

treasure_map = ["_" for _ in range(size)]

print(f"selamat datang di Treasure Hunt ! Peta memiliki {size} lokasi (0 hingga {size-1}). ")
treasure_index = random.randint(0, size-1)
print(f"Harta karun telah disembunyikan di lokasi acak. Cobalah untuk menemukannya!")
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentan yang benar.")
  treasure_index = int(input(f"Masukan lokasi harta karun (0 hingga {size-1}): "))

treasure_map[treasure_index] = "X"

def play_treasure_hunt():
  print ("\nHarta karun telah disembunyikan! Sekarang giliran pemain menebak")
  print ("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  while True:
    print ("\nPeta saat ini: ", ["_" for _ in range(size)])
    try:
      guess = int(input(f"Masukkan indeks tebakanmu (0 hingga {size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue

    if guess < 0 or guess >= size:
      print("Indeks tidak valid, pilih antara 0 hingga", size-1)
      continue

    if treasure_map[guess] == "X":
      print("Selamat! Kamu menemukan harta karun di lokasi:", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini. Coba lagi!")

play_treasure_hunt()
# Out:
# Masukkan ukuran peta: 5
# selamat datang di Treasure Hunt ! Peta memiliki 5 lokasi (0 hingga 4).
# Harta karun telah disembunyikan di lokasi acak. Cobalah untuk menemukannya!
#
# Harta karun telah disembunyikan! Sekarang giliran pemain menebak
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 4): 2
# Tidak ada harta di lokasi ini. Coba lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 4): 1
# Tidak ada harta di lokasi ini. Coba lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 4): 3
# Tidak ada harta di lokasi ini. Coba lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0 hingga 4): 4
# Selamat! Kamu menemukan harta karun di lokasi: 4
